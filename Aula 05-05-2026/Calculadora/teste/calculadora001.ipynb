# %%
# Programa Calculadora
# Descrição: 
# Este programa é uma calculadora com as quatro operações básicas. Ele deverá rodar no terminal de linhas de comando.
# Autor: Franco Mendes de Souza
# Data: 28/04/2026
# Versão: 0.0.1

# %%
# Alocação de Memória

# %%
# Entrada de dados

# %%
# Processamento da adição

def soma(x, y):
    z = x + y
    return z

# %%
# Processamento da subtração

def sub(x,y):
    z = x - y
    return z

# %%
# Processamento da multiplicação

def multi(x,y):
    z = x*y
    return z

# %%
# Processamento da divisão

def div(x,y):
    if y == 0:
        z = "Nao existe divisão por zero"
    else:
        z = x/y
    return z

# %%
# Saída
# Out:
# 'Nao existe divisão por zero'
