# %% [markdown]
# # Aula 19/05/2026

# %% [markdown]
# ## Exemplo 1: Aplicação que processa dados em um arquivo de texto

# %%
# leitura do arquivo de dados

# %%
# Lista que armazena os dados lidos

dados = [ ['31/12/2020', 100, 90, 5] ,
          ['31/12/2021', 120, 112, 6] ,
          ['31/12/2022', 110, 109, 3] , 
          ['31/12/2023', 109, 106, 1] , 
          ['31/12/2024', 103, 97, 1] , 
          ['31/12/2025', 93, 79, 1] ]

# %%
# Transformação f1 que corrige falsificação de dados

dados_corretos = [ ['31/12/2020', 100, 90, 5] , 
          ['31/12/2021', 109, 101, 6] ,
          ['31/12/2022', 110, 109, 3] , 
          ['31/12/2023', 109, 106, 1] , 
          ['31/12/2024', 103, 97, 1] , 
          ['31/12/2025', 93, 79, 1] ]
