# %% [markdown]
# # Teste do módulo main

# %%
def main():
    """Esta é a função principal da aplicação que consome a API do módulo LivroTexto"""
    pass

# %%
if __name__ == '__main__':
    main()
