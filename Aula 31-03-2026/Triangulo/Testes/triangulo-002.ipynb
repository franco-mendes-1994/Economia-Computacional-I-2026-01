# %%
"""

# Programa triângulo

Descrição: Este programa cria um triangulo

**Autor: Franco Mendes de Souza**

**Data: 31/03/2026**

**Versão: 0.0.2**

"""
# Out:
# '\n\n# Programa triângulo\n\nDescrição: Este programa cria um triangulo\n\n**Autor: Franco Mendes de Souza**\n\n**Data: 31/03/2026**\n\n**Versão: 0.0.1**\n\n'

# %%
# Alocação de memória

area = 0.0
base = 0.0
altura = 0.0
lado_1 = 0.0
lado_2 = 0.0
lado_3 = 0.0
parte_menor = 0.0
parte_maior = 0.0
triangulo = [lado_1, lado_2, lado_3]
i = 0

# %%
# Entrada de dados

while i < 3:
    triangulo[i] = float(input("\nDigite um lado do triângulo que você quer calcular a área: "))
    i += 1

print(triangulo)
# Out:
# Digite um lado do triângulo que você quer calcular a área:  5
#
# Digite um lado do triângulo que você quer calcular a área:  12
#
# Digite um lado do triângulo que você quer calcular a área:  13
# [5.0, 12.0, 13.0]

# %%
# Processamento de dados

base = triangulo[0]

# %%
## Cálculo das partes

# %%
# Saída de dados

print(f"A área do quadrado de lado {lado} é igual a {area}.")
