# %% [markdown]
# # testa a entrada e saída dos dados

# %%
def reader():
    pass

# %%
def reader():
    i = 0
    dados = [0,0]
    while i < 2:
        dados[i] = float(input(f"Digite a parcela {i + 1}: "))
        i += 1
    return dados

# %%
dados = reader()
# Out:
# Digite a parcela 1:  2
# Digite a parcela 2:  3

# %%
dados
# Out:
# [2.0, 3.0]

# %%
def writer():
    pass

# %%
def writer(dados: list) -> None:
    with open('arquivo.txt', 'w', encoding = 'utf-8') as arquivo:
        conteudo = arquivo.write(str(dados))

# %% [raw]
# # tentar executar depois, provavelmente é um problema de memória. O código acima deve criar um arquivo txt com os dados informados

# %%
writer(dados)

# %%
# Out:
# Digite a parcela 1:  2
# Digite a parcela 2:  3

# %%
dados
# Out:
# [2.0, 3.0]
