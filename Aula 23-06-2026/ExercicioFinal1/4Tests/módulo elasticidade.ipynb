# %%
import math
import pandas as pd

def elastic(quant: pd.DataFrame, prec: pd.DataFrame) -> list:
    elastic = list()
    elastic.append(1)
    for i in range(1, len(quant)):
        aux1 = quant.iloc[i,1] / quant.iloc[0,1]
        aux2 = math.log(aux1)
        aux3 = prec.iloc[i,1] / prec.iloc[0,1]
        aux4 = math.log(aux3)
        aux5 =  aux2 / aux4
        elastic.append(aux5)
    return elastic

# %%
quant = "Consumo aparente GLP IPEADATA.csv"
prec = "Preço GLP IPEADATA.csv"

# %%
import pandas as pd

def open_data(df: str):
    return pd.read_csv(df)
    
def clean_data_1(df):
    return df.head(len(df) - 2)

def clean_data_2(df):
    return df.tail(len(df) - 6)

# %%
dado1 = open_data(quant)
clean_dado1 = clean_data_1(dado1)

dado2 = open_data(prec)
clean_dado2 = clean_data_2(dado2)

# %%
teste = elastic(clean_dado1, clean_dado2)
teste
# Out:
# [1,
#  0.1245685666747899,
#  0.10710015023332799,
#  0.13541426411628232,
#  0.09957863590742032,
#  0.06706261458869642,
#  0.06617162286084415,
#  -0.3278212964152488,
#  -18.085378270082632,
#  0.3078720309407591,
#  -0.24852181046941443,
#  4.505473294994485,
#  1.293990049069496,
#  0.6224422393594823,
#  2.395261137832694,
#  -1.0422401883638182,
#  -1.0534268857544382,
#  -1.2021448980725185,
#  -1.2993745207899121,
#  -1.4383060849590308,
#  -1.8043919091886595,
#  -1.9855874902377246,
#  -1.924725208822787,
#  -2.265480722990629,
#  -2.533899939587554,
#  -2.600078897133578,
#  -2.582868935315604,
#  -2.811399554757969,
#  -2.8165336214277037,
#  -2.8548482889824247,
#  -3.0483430266622142,
#  -3.2583055900463584,
#  -3.3115020716840347,
#  -3.37220416376692,
#  -3.5590949951769417,
#  -3.754379368583067,
#  -4.239070436725529,
#  -4.9148678452132115,
#  -5.595028768376802,
#  -7.19152999110465,
#  -7.410745153667653,
#  -7.648812762032621,
#  -17.251937715117847,
#  -301.0088621508475,
#  -55.07310253414225,
#  -50.60825909150099]

# %%
type(clean_dado2.iloc[0,1])
# Out:
# numpy.float64

# %%
result = elastic(clean_dado1, clean_dado2)
result
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 result = elastic(clean_dado1, clean_dado2)
#       2 result
#
# Cell In[37], line 11, in elastic(quant, prec)
#       7         aux1 = quant.iloc[i,1] / quant.iloc[0,1]
#       8         aux2 = math.log(aux1)
#       9         aux3 = prec.iloc[i,1] / prec.iloc[0,1]
#      10         aux4 = math.log(aux3)
# ---> 11         aux5 =  aux2 / aux4
#      12         elastic.append(aux5)
#      13     return elastic
#
# ZeroDivisionError: float division by zero
