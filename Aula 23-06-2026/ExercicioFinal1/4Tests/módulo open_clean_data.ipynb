# %%
import pandas as pd

teste = pd.read_csv("Preço GLP IPEADATA.csv")

# %%
# teste

# teste.iloc[: ,1]

# %%
teste = teste.tail(len(teste) - 6)

# %%
teste2 = pd.read_csv("Consumo aparente GLP IPEADATA.csv")
#teste2

# %%
def open_data(df: str):
    return pd.read_csv(df)

# %%
def clean_data_1(df):
    return df.head(len(df) - 2)

# %%
def clean_data_2(df):
    return df.tail(len(df) - 6)

# %%
teste = "Consumo aparente GLP IPEADATA.csv"
teste2 = "Preço GLP IPEADATA.csv"

teste3 = open_data(teste2)
teste3

teste4 = clean_data_2(teste3)
teste4
# Out:
#     Data  \
# 6   1979
# 7   1980
# 8   1981
# 9   1982
# 10  1983
# 11  1984
# 12  1985
# 13  1986
# 14  1987
# 15  1988
# 16  1989
# 17  1990
# 18  1991
# 19  1992
# 20  1993
# 21  1994
# 22  1995
# 23  1996
# 24  1997
# 25  1998
# 26  1999
# 27  2000
# 28  2001
# 29  2002
# 30  2003
# 31  2004
# 32  2005
# 33  2006
# 34  2007
# 35  2008
# 36  2009
# 37  2010
# 38  2011
# 39  2012
# 40  2013
# 41  2014
# 42  2015
# 43  2016
# 44  2017
# 45  2018
# 46  2019
# 47  2020
# 48  2021
# 49  2022
# 50  2023
# 51  2024
#
#     Preço médio - gás GLP - tonelada - R$ - Agência Nacional do Petróleo (ANP) - ANP_PRGLP  \
# 6                                        8.550000e+03
# 7                                        1.391000e+04
# 8                                        2.847000e+04
# 9                                        5.142000e+04
# 10                                       1.443100e+05
# 11                                       4.931700e+05
# ...

# %%
teste3[1].iloc[0,1]
# Out:
# np.float64(80.0)

# %%
teste3[0].iloc[0,1] / teste3[1].iloc[0,1]
# Out:
# np.float64(106.875)
